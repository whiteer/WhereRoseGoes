# %%
cd ../../Google Drive/My Media/General/Education/Rose-Hulman/2013 - 2014 School year/11) Winter 2013-2014/CSSE 490/Project/Rose-Hulman Brain Drain
# Out:
# C:\Users\whiteer\Google Drive\My Media\General\Education\Rose-Hulman\2013 - 2014 School year\11) Winter 2013-2014\CSSE 490\Project\Rose-Hulman Brain Drain

# %%
import pandas as pd
import numpy as np
import urllib2
import time
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import vincent
import seaborn as sns
import json
from math import radians, cos, sin, asin, sqrt, atan2, degrees
from scipy import stats
from mpl_toolkits.basemap import Basemap
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
# %pylab --no-import-all
# %pylab inline
pylab.rcParams['figure.figsize'] = 16, 12
# Out:
# Using matplotlib backend: Qt4Agg
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib

# %%
def strip(inputString):
    if inputString == "" | inputString.upper() == 'Na':
        return np.NAN
    return inputString.strip().replace("-", " ")

def stripAndUpperCase(inputString):
    if inputString == "":
        return np.NAN
    return inputString.strip().replace("-", " ").upper()

def stripAndUpperCaseRemoveSlash(inputString):
    if inputString == "":
        return np.NAN
    return inputString.strip().replace("/", " ").upper()

def stripAndTitle(inputString):
    if inputString == "":
        return np.NAN
    return inputString.strip().replace("-", " ").title()

# %%
data = pd.read_csv('Stats_for_Elias_White.csv', header = 0, names = ['City', 'State','Major','Salary'], converters = {'City' : stripAndTitle, 'State' : stripAndUpperCase, 'Major' : stripAndUpperCaseRemoveSlash})

# %%
data.City = data.City.map(lambda city: 'Annapolis Junction' if (city == 'Annapolis J') | (city == 'Annapolis Junction,') else city)
data.City = data.City.map(lambda city: 'Cannonsburg' if (city == 'Cannonsbrug') else city)
data.City = data.City.map(lambda city: 'Chattanooga' if (city == 'Chatanooga') else city)
data.City = data.City.map(lambda city: 'Cincinnati' if (city == 'Cincinatti') else city)
data.City = data.City.map(lambda city: 'Colorado Springs' if (city == 'Colorado Srings') else city)
data.City = data.City.map(lambda city: 'Crawfordsville' if (city == 'Crawforsville') else city)
data.City = data.City.map(lambda city: 'Deer Park' if (city == 'Deer Park,') else city)
data.City = data.City.map(lambda city: 'Ellicott City' if (city == 'Ellicot City') else city)
data.City = data.City.map(lambda city: 'Fairfax' if (city == 'Farifax') else city)
data.City = data.City.map(lambda city: 'Fort Meade' if (city == 'Fort Mead') | (city == 'Ft. Meade') else city)
data.City = data.City.map(lambda city: 'Houston' if (city == 'Hoston') else city)
data.City = data.City.map(lambda city: 'Fort Wayne' if (city == 'Ft. Wayne') else city)
data.City = data.City.map(lambda city: 'Indianapolis' if (city == 'Inidianapolis') else city)
data.City = data.City.map(lambda city: 'Lafayette' if (city == 'Layfayette') else city)
data.City = data.City.map(lambda city: 'Mount Vernon' if (city == 'Mt. Vernon') else city)
data.City = data.City.map(lambda city: 'Muncie' if (city == 'Muncy') else city)
data.City = data.City.map(lambda city: 'Orlando' if (city == 'Orlanda') else city)
data.City = data.City.map(lambda city: 'Osh Kosh' if (city == 'Oshkosh') else city)
data.City = data.City.map(lambda city: 'Prudhoe Bay' if (city == 'Prudoebay') else city)
data.City = data.City.map(lambda city: 'San Antonio' if (city == "San Antonio'") else city)
data.City = data.City.map(lambda city: 'Seattle' if (city == "Seatlle") else city)
data.City = data.City.map(lambda city: 'Seymour' if (city == "Semour") else city)
data.City = data.City.map(lambda city: 'Spartanburg' if (city == "Spartenburg") else city)
data.City = data.City.map(lambda city: 'Virginia Beach' if (city == "Virgina Beach") else city)
data.City = data.City.map(lambda city: 'West Lafayette' if (city == "West Lafayette,") else city)
data.City = data.City.map(lambda city: "Steven's Point" if (city == "Steven\x92S Point,") else city)
data.City = data.City.map(lambda city: "Tucson" if (city == "Tuczon") else city)
data.City = data.City.map(lambda city: "Kokomo" if (city == 'Kokoma') else city)

# %%
data = data.dropna()
data.index.names = [None]
data.index = np.arange(len(data))

# %%
data['CityState'] = data[['City','State']].apply(tuple, axis = 1)

# %%
salary = data.Salary.tolist()

# %%
salary.sort()

# %%
salary
# Out:
# [24500L,
#  33000L,
#  33250L,
#  35000L,
#  35000L,
#  37200L,
#  38000L,
#  40000L,
#  40000L,
#  42000L,
#  42000L,
#  42000L,
#  42000L,
#  42000L,
#  42000L,
#  42000L,
#  42240L,
#  42900L,
#  43000L,
#  43000L,
#  43521L,
#  44000L,
#  44000L,
#  44000L,
#  44000L,
#  44000L,
#  44176L,
#  44512L,
#  45000L,
#  45000L,
#  45000L,
#  45000L,
#  45000L,
#  45000L,
#  45000L,
#  45000L,
#  45000L,
#  45006L,
#  45192L,
#  45760L,
#  45780L,
#  46280L,
#  47000L,
#  47500L,
#  47500L,
#  47800L,
#  47840L,
#  47840L,
#  47840L,
#  48000L,
#  48000L,
#  48000L,
#  48000L,
#  48000L,
#  48000L,
#  48000L,
#  48000L,
#  48000L,
#  48000L,
#  48000L,
#  48000L,
#  48000L,
#  48000L,
#  48500L,
#  48500L,
#  48500L,
#  48960L,
#  49000L,
#  49800L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50000L,
#  50086L,
#  50100L,
#  50400L,
#  50400L,
#  50400L,
#  50400L,
#  50400L,
#  50400L,
#  50400L,
#  50400L,
#  50443L,
#  50500L,
#  50500L,
#  50500L,
#  51000L,
#  51000L,
#  51500L,
#  52000L,
#  52000L,
#  52000L,
#  52000L,
#  52000L,
#  52000L,
#  52000L,
#  52000L,
#  52000L,
#  52000L,
#  52000L,
#  52000L,
#  52000L,
#  52000L,
#  52200L,
#  52300L,
#  52500L,
#  52500L,
#  53000L,
#  53000L,
#  53000L,
#  53000L,
#  53000L,
#  53000L,
#  53000L,
#  53000L,
#  53000L,
#  53000L,
#  53000L,
#  53000L,
#  53000L,
#  53012L,
#  53100L,
#  53400L,
#  53500L,
#  53500L,
#  53500L,
#  53520L,
#  53575L,
#  53760L,
#  53788L,
#  53992L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54000L,
#  54080L,
#  54100L,
#  54323L,
#  54486L,
#  54486L,
#  54500L,
#  54500L,
#  54500L,
#  54500L,
#  54750L,
#  54800L,
#  54875L,
#  54879L,
#  54879L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55000L,
#  55200L,
#  55200L,
#  55368L,
#  55500L,
#  55500L,
#  55500L,
#  55600L,
#  55800L,
#  55825L,
#  55844L,
#  55844L,
#  55900L,
#  56000L,
#  56000L,
#  56000L,
#  56000L,
#  56000L,
#  56000L,
#  56000L,
#  56000L,
#  56000L,
#  56000L,
#  56000L,
#  56000L,
#  56000L,
#  56000L,
#  56000L,
#  56000L,
#  56160L,
#  56200L,
#  56368L,
#  56400L,
#  56400L,
#  56400L,
#  56400L,
#  56400L,
#  56400L,
#  56400L,
#  56400L,
#  56400L,
#  56426L,
#  56500L,
#  56500L,
#  56500L,
#  56500L,
#  56500L,
#  56500L,
#  56500L,
#  56520L,
#  56575L,
#  56600L,
#  56657L,
#  56659L,
#  56800L,
#  56844L,
#  56900L,
#  57000L,
#  57000L,
#  57000L,
#  57000L,
#  57000L,
#  57000L,
#  57000L,
#  57000L,
#  57000L,
#  57000L,
#  57192L,
#  57200L,
#  57480L,
#  57500L,
#  57500L,
#  57500L,
#  57500L,
#  57500L,
#  57500L,
#  57500L,
#  57600L,
#  57600L,
#  57600L,
#  57600L,
#  57700L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58000L,
#  58240L,
#  58500L,
#  58500L,
#  58500L,
#  58500L,
#  58500L,
#  58500L,
#  58500L,
#  58500L,
#  58500L,
#  58500L,
#  58500L,
#  58500L,
#  58500L,
#  58500L,
#  58800L,
#  58800L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59000L,
#  59004L,
#  59100L,
#  59280L,
#  59500L,
#  59500L,
#  59500L,
#  59500L,
#  59508L,
#  59600L,
#  59600L,
#  59800L,
#  59800L,
#  59800L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60000L,
#  60008L,
#  60049L,
#  60132L,
#  60300L,
#  60300L,
#  60326L,
#  60500L,
#  60500L,
#  60500L,
#  60600L,
#  60700L,
#  60800L,
#  60900L,
#  60999L,
#  60999L,
#  60999L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61000L,
#  61200L,
#  61200L,
#  61200L,
#  61200L,
#  61200L,
#  61200L,
#  61250L,
#  61250L,
#  61500L,
#  61500L,
#  61500L,
#  61800L,
#  61800L,
#  61900L,
#  61900L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62000L,
#  62004L,
#  62100L,
#  62100L,
#  62100L,
#  62250L,
#  62250L,
#  62400L,
#  62400L,
#  62400L,
#  62400L,
#  62400L,
#  62400L,
#  62500L,
#  62500L,
#  62500L,
#  62500L,
#  62500L,
#  62500L,
#  62500L,
#  62500L,
#  62500L,
#  62500L,
#  62500L,
#  62500L,
#  62500L,
#  62500L,
#  62500L,
#  62700L,
#  62700L,
#  62950L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63000L,
#  63100L,
#  63100L,
#  63480L,
#  63500L,
#  63500L,
#  63500L,
#  63500L,
#  63600L,
#  63700L,
#  63750L,
#  63780L,
#  63780L,
#  63780L,
#  63780L,
#  63800L,
#  63800L,
#  63900L,
#  63900L,
#  63913L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64000L,
#  64008L,
#  64008L,
#  64200L,
#  64224L,
#  64224L,
#  64500L,
#  64500L,
#  64500L,
#  64500L,
#  64500L,
#  64600L,
#  64600L,
#  64900L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65000L,
#  65040L,
#  65100L,
#  65100L,
#  65172L,
#  65500L,
#  65500L,
#  65500L,
#  65500L,
#  65600L,
#  65700L,
#  65700L,
#  65800L,
#  65800L,
#  65800L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66000L,
#  66100L,
#  66228L,
#  66228L,
#  66500L,
#  66500L,
#  66500L,
#  66500L,
#  66780L,
#  66800L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67000L,
#  67008L,
#  67008L,
#  67008L,
#  67008L,
#  67100L,
#  67500L,
#  67500L,
#  67500L,
#  67500L,
#  67512L,
#  67560L,
#  67584L,
#  67655L,
#  68000L,
#  68000L,
#  68000L,
#  68000L,
#  68000L,
#  68000L,
#  68000L,
#  68000L,
#  68000L,
#  68000L,
#  68000L,
#  68000L,
#  68000L,
#  68000L,
#  68000L,
#  68000L,
#  68904L,
#  68904L,
#  69000L,
#  69000L,
#  69000L,
#  69000L,
#  69000L,
#  69000L,
#  69000L,
#  69451L,
#  69600L,
#  69900L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  70000L,
#  71000L,
#  71000L,
#  71000L,
#  72000L,
#  72000L,
#  72000L,
#  72000L,
#  72000L,
#  72000L,
#  72000L,
#  72800L,
#  73000L,
#  73000L,
#  74000L,
#  74000L,
#  74000L,
#  74400L,
#  75000L,
#  75000L,
#  75000L,
#  75000L,
#  75000L,
#  75000L,
#  75000L,
#  75000L,
#  75000L,
#  75000L,
#  75000L,
#  75000L,
#  75000L,
#  75000L,
#  76000L,
#  77000L,
#  77000L,
#  78000L,
#  78000L,
#  78000L,
#  80000L,
#  80000L,
#  80000L,
#  80000L,
#  80000L,
#  80000L,
#  80000L,
#  80000L,
#  80400L,
#  81000L,
#  81000L,
#  81000L,
#  81000L,
#  81000L,
#  82000L,
#  82000L,
#  82160L,
#  83000L,
#  83000L,
#  83000L,
#  83000L,
#  85000L,
#  85000L,
#  85000L,
#  85000L,
#  85200L,
#  87000L,
#  87000L,
#  87000L,
#  88000L,
#  88000L,
#  88000L,
#  89000L,
#  89000L,
#  90000L,
#  90000L,
#  90000L,
#  90000L,
#  90000L,
#  90000L,
#  90000L,
#  90000L,
#  90000L,
#  90000L,
#  90000L,
#  90000L,
#  90000L,
#  90000L,
#  90000L,
#  91000L,
#  92000L,
#  93000L,
#  93500L,
#  94000L,
#  94000L,
#  94000L,
#  95000L,
#  95000L,
#  95000L,
#  95000L,
#  95000L,
#  95000L,
#  95000L,
#  95000L,
#  95000L,
#  96000L,
#  98000L,
#  100000L,
#  100300L,
#  102000L,
#  102500L,
#  103000L,
#  105000L,
#  107000L,
#  115000L]

# %%
plot(salary)

# %%
data.Salary.hist(color='k', alpha=0.5, bins=50)

# %%
arr = data.CityState.unique()
arr = arr.tolist()
arr.sort()
len(arr)
# Out:
# 302

# %%
arr
# Out:
# [('Addision', 'TX'),
#  ('Akron', 'OH'),
#  ('Albuquerque', 'NM'),
#  ('Alexandria', 'LA'),
#  ('Alexandria', 'VA'),
#  ('Amherst', 'NY'),
#  ('Anderson', 'IN'),
#  ('Annapolis', 'MD'),
#  ('Annapolis Junction', 'MD'),
#  ('Arlington', 'VA'),
#  ('Assumption', 'IL'),
#  ('Athens', 'OH'),
#  ('Auburn Hills', 'MI'),
#  ('Austin', 'TX'),
#  ('Austing', 'TX'),
#  ('Avenel', 'NJ'),
#  ('Bakersfield', 'CA'),
#  ('Balikpapan', 'INDONESIA'),
#  ('Baltimore', 'MD'),
#  ('Batesville', 'IN'),
#  ('Baton Rouge', 'LA'),
#  ('Baytown', 'TX'),
#  ('Beaumont', 'TX'),
#  ('Beckett Ridge', 'OH'),
#  ('Bedford', 'IN'),
#  ('Belleville', 'MI'),
#  ('Bellevue', 'WA'),
#  ('Bellingham', 'WA'),
#  ('Bloomington', 'IN'),
#  ('Bloomington', 'MN'),
#  ('Boston', 'MA'),
#  ('Boulder', 'CO'),
#  ('Bowling Green', 'KY'),
#  ('Brazil', 'IN'),
#  ('Bremen', 'IN'),
#  ('Brighton', 'CO'),
#  ('Broussard', 'LA'),
#  ('Brownsburg', 'IN'),
#  ('Buffalo Grove', 'IL'),
#  ('Burleson', 'TX'),
#  ('Burlington', 'VT'),
#  ('Burns Harbor', 'IL'),
#  ('Burns Harbor', 'IN'),
#  ('Cannonsburg', 'PA'),
#  ('Canton', 'OH'),
#  ('Cape Giradeaux', 'MO'),
#  ('Carmel', 'IN'),
#  ('Carmichaels', 'PA'),
#  ('Catlettsburg', 'KY'),
#  ('Cedar Rapids', 'IA'),
#  ('Cedar Rapids', 'MI'),
#  ('Champaign', 'IL'),
#  ('Charleston', 'SC'),
#  ('Charlotte', 'NC'),
#  ('Chattanooga', 'TN'),
#  ('Chicago', 'IL'),
#  ('Chicago', 'IN'),
#  ('Chino', 'CA'),
#  ('Cicero', 'IL'),
#  ('Cincinnati', 'OH'),
#  ('Cleveland', 'OH'),
#  ('Clinton', 'IA'),
#  ('Clinton', 'IN'),
#  ('Coldwater', 'MI'),
#  ('Colorado Springs', 'CO'),
#  ('Columbia', 'MD'),
#  ('Columbus', 'IN'),
#  ('Columbus', 'OH'),
#  ('Connersville', 'IN'),
#  ('Conshohoken', 'PA'),
#  ('Conway', 'AR'),
#  ('Coon Rapids', 'MN'),
#  ('Coopersburg', 'PA'),
#  ('Cordyn', 'IN'),
#  ('Courtland', 'AL'),
#  ('Crane', 'IN'),
#  ('Crawfordsville', 'IN'),
#  ('Crown Point', 'IN'),
#  ('Dallas', 'TX'),
#  ('Danville', 'IL'),
#  ('Dayton', 'OH'),
#  ('Dearborn', 'MI'),
#  ('Decatur', 'IL'),
#  ('Deer Park', 'TX'),
#  ('Denver', 'CO'),
#  ('Des Plaines', 'IL'),
#  ('Dover', 'NJ'),
#  ('Downers Grove', 'IL'),
#  ('Duncan', 'OK'),
#  ('Edwardsport', 'IN'),
#  ('El Paso', 'TX'),
#  ('Ellicott City', 'MD'),
#  ('Erlanger', 'KY'),
#  ('Evandale', 'OH'),
#  ('Evansville', 'IN'),
#  ('Evansville', 'MN'),
#  ('Fairfax', 'VA'),
#  ('Farmington', 'NM'),
#  ('Farmington Hills', 'MI'),
#  ('Findlay', 'OH'),
#  ('Fishers', 'IN'),
#  ('Florham Park', 'NJ'),
#  ('Fontanet', 'IN'),
#  ('Fort Meade', 'MD'),
#  ('Fort Wayne', 'IN'),
#  ('Fosteria', 'OH'),
#  ('Frankfort', 'IN'),
#  ('Franklin', 'WI'),
#  ('Freeport', 'TX'),
#  ('Fremont', 'WV'),
#  ('Gainesville', 'FL'),
#  ('Galesburg', 'IL'),
#  ('Gary', 'IN'),
#  ('Garyville', 'LA'),
#  ('Georgetown', 'KY'),
#  ('Georgetown', 'SC'),
#  ('Glen??', 'IL'),
#  ('Goodlettsville', 'TN'),
#  ('Grand Junction', 'CO'),
#  ('Greenfield', 'IN'),
#  ('Greensboro', 'GA'),
#  ('Greensboro', 'NC'),
#  ('Greensburg', 'IN'),
#  ('Greenville', 'SC'),
#  ('Greenwood', 'IN'),
#  ('Hawesville', 'KY'),
#  ('Highland Heights', 'KY'),
#  ('Hillard', 'OH'),
#  ('Hobbs', 'NM'),
#  ('Homer City', 'PA'),
#  ('Hope', 'IN'),
#  ('Houston', 'TX'),
#  ('Hudson', 'MA'),
#  ('Idaho Falls', 'ID'),
#  ('Indianapolis', 'IN'),
#  ('Ipsilanti', 'MI'),
#  ('Jamestown', 'KY'),
#  ('Jupiter', 'FL'),
#  ('Kanazawa', 'JAPAN'),
#  ('Kansas City', 'KS'),
#  ('Kansas City', 'MO'),
#  ('Kilgore', 'TX'),
#  ('Knoxville', 'TN'),
#  ('Kokomo', 'IN'),
#  ('Lafayette', 'IN'),
#  ('Lafayette', 'LA'),
#  ('Laporte', 'IN'),
#  ('Lexington', 'KY'),
#  ('Lincoln', 'NB'),
#  ('Lombard', 'IL'),
#  ('Los Angeles', 'CA'),
#  ('Louisville', 'KY'),
#  ('Lyle', 'IL'),
#  ('Madison', 'IN'),
#  ('Madison', 'WI'),
#  ('Mahwah', 'NJ'),
#  ('Marion', 'IN'),
#  ('Marshall', 'IL'),
#  ('Marshall', 'MN'),
#  ('Marshall', 'TX'),
#  ('Marshall Space Flight Center', 'AL'),
#  ('Martinsville', 'IN'),
#  ('Mcgregor', 'TX'),
#  ('Memphis', 'TN'),
#  ('Merrillville', 'IN'),
#  ('Miami', 'FL'),
#  ('Michigan City', 'IN'),
#  ('Midland', 'MI'),
#  ('Midland', 'TX'),
#  ('Milford', 'OH'),
#  ('Milwaukee', 'WI'),
#  ('Minneapolis', 'MN'),
#  ('Minster', 'OH'),
#  ('Monroeville', 'IN'),
#  ('Montgomery', 'AL'),
#  ('Montgomery', 'PA'),
#  ('Monticello', 'IN'),
#  ('Mooresville', 'IN'),
#  ('Morris', 'IL'),
#  ('Morristown', 'IN'),
#  ('Morristown', 'TN'),
#  ('Mossville', 'IL'),
#  ('Mount Vernon', 'IN'),
#  ('Mountain View', 'CA'),
#  ('Muncie', 'IN'),
#  ('Muncie', 'PA'),
#  ('Murpheesboro', 'TN'),
#  ('Muscatine', 'IA'),
#  ('Na', 'NA'),
#  ('Neenau', 'WI'),
#  ('New Hudson', 'MI'),
#  ('New Iberia', 'LA'),
#  ('New York City', 'NY'),
#  ('Norfolk', 'VA'),
#  ('Northbrook', 'IL'),
#  ("O'Fallon", 'IL'),
#  ('Oakbrook Terrace', 'IL'),
#  ('Odessa', 'TX'),
#  ('Olathe', 'KS'),
#  ('Orlando', 'FL'),
#  ('Osh Kosh', 'WI'),
#  ('Owensboro', 'KY'),
#  ('Palo Alto', 'CA'),
#  ('Pampa', 'TX'),
#  ('Paris', 'IL'),
#  ('Pekin', 'IL'),
#  ('Pendleton', 'IN'),
#  ('Peoria', 'IL'),
#  ('Perrysburg', 'OH'),
#  ('Petaluma', 'CA'),
#  ('Phoenix', 'AZ'),
#  ('Pittsburgh', 'PA'),
#  ('Plano', 'TX'),
#  ('Plymouth', 'MN'),
#  ('Point Beach', 'WI'),
#  ('Portland', 'OR'),
#  ('Princton', 'IN'),
#  ('Prudhoe Bay', 'AK'),
#  ('Prudoebay,', 'AK'),
#  ('Raleigh', 'NC'),
#  ('Redmond', 'WA'),
#  ('Research Triangle Park', 'NC'),
#  ('Reston', 'VA'),
#  ('Richardson', 'TX'),
#  ('Richland', 'MI'),
#  ('Richland', 'WA'),
#  ('Riverdale', 'IL'),
#  ('Robinson', 'IL'),
#  ('Rochester', 'NY'),
#  ('Rock Springs', 'WY'),
#  ('Rocky Mt.', 'NC'),
#  ('Salem', 'IN'),
#  ('San Antonio', 'TX'),
#  ('San Antonio,', 'TX'),
#  ('San Diego', 'CA'),
#  ('San Mateo', 'CA'),
#  ('Sandiego', 'CA'),
#  ('Santa Barbara', 'CA'),
#  ('Seattle', 'WA'),
#  ('Seymour', 'IN'),
#  ('Sharonville', 'OH'),
#  ('Shelbyville', 'IN'),
#  ('Shelbyville', 'KY'),
#  ('Shippensburg', 'PA'),
#  ('Shreveport', 'LA'),
#  ('Skillman', 'NJ'),
#  ('South Bend', 'IN'),
#  ('Southfield', 'MI'),
#  ('Spartanburg', 'SC'),
#  ('Spencer', 'IN'),
#  ('Springfield', 'OR'),
#  ('St. Charles', 'IL'),
#  ('St. Louis', 'IN'),
#  ('St. Louis', 'MO'),
#  ('St. Paul', 'MN'),
#  ('Steelton', 'PA'),
#  ('Sterling', 'VA'),
#  ("Steven's Point", 'WI'),
#  ('Sturgeon Bay', 'WI'),
#  ('Sullivan', 'IL'),
#  ('Tampa', 'FL'),
#  ('Temecula', 'CA'),
#  ('Terre Haute', 'IN'),
#  ('Texarkana', 'AR'),
#  ('Texarkana', 'TX'),
#  ('Toledo', 'OH'),
#  ('Trenton', 'MI'),
#  ('Troy', 'MI'),
#  ('Tucson', 'AZ'),
#  ('Tyler', 'TX'),
#  ('Valley Forge', 'PA'),
#  ('Valliant', 'OK'),
#  ('Vernon Hills', 'IL'),
#  ('Vero Beach', 'FL'),
#  ('Verona', 'WI'),
#  ('Virginia Beach', 'VA'),
#  ('Walled Lake', 'MI'),
#  ('Walnut Creek', 'CA'),
#  ('Warren', 'MI'),
#  ('Warrenville', 'IL'),
#  ('Warsau', 'WI'),
#  ('Warsaw', 'IN'),
#  ('Washington', 'DC'),
#  ('Waterloo', 'IN'),
#  ('Wauwatosa', 'WI'),
#  ('West Chester', 'OH'),
#  ('West Lafayette', 'IN'),
#  ('West Terre Haute', 'IN'),
#  ('Westfield', 'IN'),
#  ('Westford', 'MA'),
#  ('Westin', 'WV'),
#  ('Westmont', 'IL'),
#  ('Wheeling,', 'IL'),
#  ('Whitehall', 'MI'),
#  ('Whiting', 'WI'),
#  ('Wichita Falls', 'TX'),
#  ('Wickliffe', 'KY'),
#  ('Williston', 'ND'),
#  ('Woburn', 'MA'),
#  ('Woodland Hills', 'CA'),
#  ('Wright Patterson Afb', 'OH'),
#  ('Zeeland', 'MI')]

# %%
data.head(60)
# Out:
#                   City State     Major  Salary                 CityState
# 0         Indianapolis    IN       CHE   58000        (Indianapolis, IN)
# 1         Indianapolis    IN        EE   58000        (Indianapolis, IN)
# 2              Clinton    IA       CHE   63000             (Clinton, IA)
# 3              Decatur    IL       CHE   63100             (Decatur, IL)
# 4              Clinton    IA       CHE   63000             (Clinton, IA)
# 5              Lincoln    NB        EE   61000             (Lincoln, NB)
# 6              Decatur    IL        EE   62500             (Decatur, IL)
# 7             Addision    TX        CE   45000            (Addision, TX)
# 8               Dallas    TX        CE   45000              (Dallas, TX)
# 9         Merrillville    IN        ME   54000        (Merrillville, IN)
# 10          Evansville    IN        EE   60800          (Evansville, IN)
# 11               Dover    NJ        ME   60000               (Dover, NJ)
# 12               Dover    NJ        ME   60500               (Dover, NJ)
# 13        Indianapolis    IN       CPE   55000        (Indianapolis, IN)
# 14        Indianapolis    IN        CS   63000        (Indianapolis, IN)
# 15        Indianapolis    IN        SE   50000        (Indianapolis, IN)
# 16        Indianapolis    IN        SE   60000        (Indianapolis, IN)
# 17        Indianapolis    IN        ME   64000        (Indianapolis, IN)
# 18        Indianapolis    IN        ME   64008        (Indianapolis, IN)
# 19        Indianapolis    IN        EE   65000        (Indianapolis, IN)
# 20             Chicago    IL        CS   52300             (Chicago, IL)
# 21             Chicago    IL        CS   55000             (Chicago, IL)
# 22             Chicago    IL        CS   60000             (Chicago, IL)
# 23             Seattle    WA        CS   90000             (Seattle, WA)
# 24             Seattle    WA        CS   90000             (Seattle, WA)
# 25             Seattle    WA        CS   90000             (Seattle, WA)
# 26             Seattle    WA        CS   90000             (Seattle, WA)
# 27             Seattle    WA        CS   90000             (Seattle, WA)
# 28             Seattle    WA        CS   90000             (Seattle, WA)
# 29             Seattle    WA        CE   52500             (Seattle, WA)
# 30        Indianapolis    IN        SE   70000        (Indianapolis, IN)
# 31             Houston    TX        ME  100000             (Houston, TX)
# 32        Indianapolis    IN       CPE   48000        (Indianapolis, IN)
# 33        Indianapolis    IN     BE CS   55000        (Indianapolis, IN)
# 34        Indianapolis    IN       CPE   59000        (Indianapolis, IN)
# 35        Burns Harbor    IN        CE   56200        (Burns Harbor, IN)
# 36        Burns Harbor    IN        ME   63900        (Burns Harbor, IN)
# 37        Burns Harbor    IN       CPE   61900        (Burns Harbor, IN)
# 38         Conshohoken    PA        EE   64900         (Conshohoken, PA)
# 39        Burns Harbor    IL       CHE   63900        (Burns Harbor, IL)
# 40              Austin    TX        CS   70000              (Austin, TX)
# 41              Denver    CO        CE   65500              (Denver, CO)
# 42         Crown Point    IN        ME   56000         (Crown Point, IN)
# 43          Greenfield    IN        ME   58000          (Greenfield, IN)
# 44           St. Louis    MO        ME   55000           (St. Louis, MO)
# 45           St. Louis    MO        ME   58000           (St. Louis, MO)
# 46        Indianapolis    IN        CS   63000        (Indianapolis, IN)
# 47         Spartanburg    SC        ME   60000         (Spartanburg, SC)
# 48  Annapolis Junction    MD        SE   73000  (Annapolis Junction, MD)
# 49  Annapolis Junction    MD        CS   72000  (Annapolis Junction, MD)
# 50  Annapolis Junction    MD        EE   72000  (Annapolis Junction, MD)
# 51           Annapolis    MD       CPE   68000           (Annapolis, MD)
# 52           Milwaukee    WI  CHE CHEM   63000           (Milwaukee, WI)
# 53             Spencer    IN        BE   57500             (Spencer, IN)
# 54             Houston    TX        ME   82000             (Houston, TX)
# 55              Austin    TX        CS   80000              (Austin, TX)
# 56        Mount Vernon    IN      CHEM   33250        (Mount Vernon, IN)
# 57      West Lafayette    IN        ME   45760      (West Lafayette, IN)
# 58          Louisville    KY       CHE   63480          (Louisville, KY)
# 59             Houston    TX        EE   61200             (Houston, TX)

# %%
uniqueCityState = data.CityState.unique()

# %%
def getGeoCoordinates((City, State)):
    replaceString = "http://maps.googleapis.com/maps/api/geocode/json?address=+REPLACEMECITY,+REPLACEMESTATE&sensor=false"    
    replaceString = replaceString.replace("REPLACEMECITY", City.replace(" ", "+"))
    replaceString = replaceString.replace("REPLACEMESTATE", State)
    XMLstream = urllib2.urlopen(replaceString).read()
    
    Location_Index = XMLstream.find("location")
    lat = float(XMLstream[XMLstream.find("lat\" : ",Location_Index) + 7:XMLstream.find(",",Location_Index)])
    lng = float(XMLstream[XMLstream.find("lng\" : ",Location_Index) + 7:XMLstream.find("\n",XMLstream.find("lng\" : ",Location_Index))])
    
    County_Index = XMLstream.rfind("short_name",0,XMLstream.find("administrative_area_level_2")) + 15
    County = XMLstream[County_Index: XMLstream.find("\n",County_Index)  - 2]
    if " County" in County:
        County = County[0: County.find(" County")]
    
    time.sleep(.5)
    return {(City, State): (lat,lng, County)}

# %%
dictionary_Lats_Longs = np.vectorize(getGeoCoordinates)(uniqueCityState)

# %%
Dictionary_Lats_Longs = {}
for i in range(dictionary_Lats_Longs.size):
    for key in dictionary_Lats_Longs[i]:
        Dictionary_Lats_Longs[key] = []
        Dictionary_Lats_Longs[key].extend(dictionary_Lats_Longs[i][key])

# %%
def assign_coordinates((City, State)):
    return Dictionary_Lats_Longs[(City, State)][0], Dictionary_Lats_Longs[(City, State)][1], Dictionary_Lats_Longs[(City, State)][2]

# %%
data['lats'], data['lons'], data['County']  = zip(*data.CityState.map(assign_coordinates))

# %%
data.to_csv('NewestVersionOfSalaryDataAndLatsLons.csv')

# %%
RoseHulmanLat = 39.4798449
RoseHulmanLon = -87.3307898

# %%
def haversine(lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    lat1 = RoseHulmanLat
    lon1 = RoseHulmanLon
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 

    # 6367 km is the radius of the Earth, .621371 miles in a km
    miles = 0.621371 * 6367 * c
    
    
    Bearing = atan2(cos(lat1)*sin(lat2)-sin(lat1)*cos(lat2)*cos(lon2-lon1), sin(lon2-lon1)*cos(lat2))
    return miles, degrees(Bearing)

# %%
data['DistFromRoseHulman'], data['BearingFromRoseHulman'] = np.vectorize(haversine)(data['lons'],lat2 = data['lats'])

# %%
data.to_csv('Newest_Vers_Of_Salary_Data_And_Dist_Bear.csv')

# %%
data.head()
# Out:
#            City State Major  Salary           CityState       lats       lons  \
# 0  Indianapolis    IN   CHE   58000  (Indianapolis, IN)  39.768403 -86.158068
# 1  Indianapolis    IN    EE   58000  (Indianapolis, IN)  39.768403 -86.158068
# 2       Clinton    IA   CHE   63000       (Clinton, IA)  41.844473 -90.188738
# 3       Decatur    IL   CHE   63100       (Decatur, IL)  39.840315 -88.954800
# 4       Clinton    IA   CHE   63000       (Clinton, IA)  41.844473 -90.188738
#
#     County  DistFromRoseHulman  BearingFromRoseHulman
# 0   Marion           65.476254              18.089697
# 1   Marion           65.476254              18.089697
# 2  Clinton          221.486386             131.591741
# 3    Macon           89.843696             163.399363
# 4  Clinton          221.486386             131.591741

# %%
data_trimmed = data.sort("DistFromRoseHulman").iloc[:-5]
data_trimmed.index.names = [None]
data_trimmed.index = np.arange(len(data_trimmed))

# %%
data_trimmed.to_csv('Newest_No_Outliers_Salary.csv')

# %%
data = pd.read_csv('Newest_No_Outliers_Salary.csv', header = 0).drop(['Unnamed: 0'], axis = 1)

# %%
data.head()
# Out:
#           City State Major  Salary              CityState       lats  \
# 0  Terre Haute    IN   CHE   75000  ('Terre Haute', 'IN')  39.466703
# 1  Terre Haute    IN    ME   78000  ('Terre Haute', 'IN')  39.466703
# 2  Terre Haute    IN    ME   42000  ('Terre Haute', 'IN')  39.466703
# 3  Terre Haute    IN  CHEM   42000  ('Terre Haute', 'IN')  39.466703
# 4  Terre Haute    IN   CPE   48000  ('Terre Haute', 'IN')  39.466703
#
#         lons County  DistFromRoseHulman  BearingFromRoseHulman
# 0 -87.413909   Vigo            4.522329            -168.451266
# 1 -87.413909   Vigo            4.522329            -168.451266
# 2 -87.413909   Vigo            4.522329            -168.451266
# 3 -87.413909   Vigo            4.522329            -168.451266
# 4 -87.413909   Vigo            4.522329            -168.451266

# %%
scatter(data_trimmed.DistFromRoseHulman,data_trimmed.Salary)

# %%
data_trimmed.head()
# Out:
#           City State Major  Salary          CityState       lats       lons  \
# 0  Terre Haute    IN   CHE   75000  (Terre Haute, IN)  39.466703 -87.413909
# 1  Terre Haute    IN    ME   78000  (Terre Haute, IN)  39.466703 -87.413909
# 2  Terre Haute    IN    ME   42000  (Terre Haute, IN)  39.466703 -87.413909
# 3  Terre Haute    IN  CHEM   42000  (Terre Haute, IN)  39.466703 -87.413909
# 4  Terre Haute    IN   CPE   48000  (Terre Haute, IN)  39.466703 -87.413909
#
#   County  DistFromRoseHulman  BearingFromRoseHulman
# 0   Vigo            4.522329            -168.451266
# 1   Vigo            4.522329            -168.451266
# 2   Vigo            4.522329            -168.451266
# 3   Vigo            4.522329            -168.451266
# 4   Vigo            4.522329            -168.451266

# %%
data_EE = pd.DataFrame(data[data.Major.str.contains('EE')])
data_EE.index.names = [None]
data_EE.index = np.arange(len(data_EE))
data_EE.Major = data_EE.Major.map(lambda s: 'EE')

# %%
scatter(data_EE.DistFromRoseHulman,data_EE.Salary)

# %%
data_CS = pd.DataFrame(data[data.Major.str.contains('CS')])
data_CS.index.names = [None]
data_CS.index = np.arange(len(data_CS))
data_CS.Major = data_CS.Major.map(lambda s: 'CS')

# %%
scatter(data_CS.DistFromRoseHulman,data_CS.Salary)

# %%
data_ME = pd.DataFrame(data[data.Major.str.contains('ME')])
data_ME.index.names = [None]
data_ME.index = np.arange(len(data_ME))
data_ME.Major = data_ME.Major.map(lambda s: 'ME')

# %%
scatter(data_ME.DistFromRoseHulman,data_ME.Salary)

# %%
data_CHE = pd.DataFrame(data[data.Major.str.contains("CHE")])
data_CHE = pd.DataFrame(data_CHE[data.Major != 'CHEM'])
data_CHE.index.names = [None]
data_CHE.index = np.arange(len(data_CHE))
data_CHE.Major = data_CHE.Major.map(lambda s: 'CHE')
# Out:
# C:\Users\whiteer\Anaconda\lib\site-packages\pandas\core\frame.py:2021: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)

# %%
data_SE = pd.DataFrame(data[data.Major.str.contains('SE')])
data_SE.index.names = [None]
data_SE.index = np.arange(len(data_SE))
data_SE.Major = data_SE.Major.map(lambda s: 'SE')

# %%
data_CPE = pd.DataFrame(data[data.Major.str.contains('CPE')])
data_CPE.index.names = [None]
data_CPE.index = np.arange(len(data_CPE))
data_CPE.Major = data_CPE.Major.map(lambda s: 'CPE')

# %%
data_CE1 = pd.DataFrame(data[data.Major.str.contains('CE')])
data_CE2 = pd.DataFrame(data[data.Major.str.contains('CIVIL')])
data_CE = pd.concat([data_CE1,data_CE2],ignore_index=True)
data_CE.index.names = [None]
data_CE.index = np.arange(len(data_CE))
data_CE.Major = data_CE.Major.map(lambda s: 'CE')

# %%
data_CHEM = pd.DataFrame(data[data.Major.str.contains("CHEM")])
data_CHEM.index.names = [None]
data_CHEM.index = np.arange(len(data_CHEM))
data_CHEM.Major = data_CHEM.Major.map(lambda s: 'CHEM')

# %%
data_new = pd.concat([data_CE,data_CHE,data_CHEM,data_CPE,data_CS,data_EE,data_ME,data_SE], ignore_index=True)

# %%
sns.violinplot(data_new.Salary, data_new.State)
sns.despine(left=True);

# %%
sns.violinplot(data_new.Salary, data_new.Major)
sns.despine(left=True);

# %%
r2 = lambda x, y: stats.pearsonr(x, y)[0] ** 2

# %%
sns.regplot(data_EE.DistFromRoseHulman,data_EE.Salary/1000.0, corr_func=r2, func_name="$R^2$")

# %%
sns.regplot(data_ME.DistFromRoseHulman,data_ME.Salary/1000.0, corr_func=r2, func_name="$R^2$")

# %%
r2 = lambda x, y: stats.pearsonr(x, y)[0] ** 2
sns.regplot(data_CS.DistFromRoseHulman,data_CS.Salary/1000.0,corr_func=r2, func_name="$R^2$", color="seagreen")

# %%
data = pd.read_csv('Newest_No_Outliers_Salary.csv', header = 0).drop(['Unnamed: 0'], axis = 1)
from IPython.core import display

# %%
js_loader = """
function verifyJSLoaded(){
    var jsapiLoaded = (typeof google === 'object' && typeof google.maps === 'object');
    console.log("Google API Loaded: " + jsapiLoaded);
    return jsapiLoaded;
}

function loadScript() {
  if (!verifyJSLoaded()) {
    console.log('Loading Google API.');
    var script = document.createElement("script");
    script.type = "text/javascript";
    script.src = "https://maps.googleapis.com/maps/api/js?sensor=false&libraries=visualization&callback=console.log";
    document.body.appendChild(script);
  }
}

loadScript();
"""
display.Javascript(js_loader)

# %%
html_template = '<div id="%s" style="width: 800px; height: 400px"></div>'
#This is to make sure the JS gets loaded before we try to load the maps
time.sleep(1)

# %%
Lat_Long_tuples = data[['lats','lons']].apply(tuple, axis = 1)

# %%
def gen_javascript(data, div_id=None):

    if div_id == None:
        div_id = key
    # Creates Javascript objects which will comprise geoData.
    coords = ',\n  '.join(["new google.maps.LatLng(%s, %s)" % tuple(pair) for pair in data])    
    template_jscript = """
    var geoData = [
    # %s
    ];
        
    var map, heatmap;
        
    function hmap_initialize() {
    
        var mapOptions = {
            zoom: 4,
            center: new google.maps.LatLng(39.8282, -98.5795),
            panControl: false,
            zoomControl: false,
            scaleControl: true,
            mapTypeControl: true,
            mapTypeControlOptions: {
              style: google.maps.MapTypeControlStyle.DROPDOWN_MENU
            }
        };
        
        map = new google.maps.Map(document.getElementById('%s'), mapOptions);
        
        var styleArray = [
            {
                featureType: "road.highway",
                elementType: "labels.text.stroke",
                stylers: [ 
                    { visibility: "off" } 
                ] 
            }
        ];

        map.setOptions({styles: styleArray});
        
        var pointArray = new google.maps.MVCArray(geoData);
        
        heatmap = new google.maps.visualization.HeatmapLayer({ data: pointArray});
        
        heatmap.setMap(map);
    }
   
    hmap_initialize();
    
    var gradient = [
        'rgba(128, 0, 38, 0)',
        'rgba(189, 0, 38, 1)',
        'rgba(227, 26, 28, 1)',    
        'rgba(252, 78, 42, 1)',
        'rgba(253, 141, 60, 1)',
        'rgba(254, 178, 76, 1)',
        'rgba(254, 217, 118, 1)',
        'rgba(255, 237, 160, 1)',
        'rgba(255, 255, 204, 1)'
    ]
    
    heatmap.set('gradient', gradient);
    heatmap.set('radius', 20);
    heatmap.set('opacity', 0.7);
"""
    return template_jscript % (coords, div_id)

# %%
key = 'Testing'
jscript = gen_javascript(Lat_Long_tuples)
display.HTML(html_template % key)
# Out:
# <div id="Testing" style="width: 800px; height: 400px"></div>

# %%
display.Javascript(jscript)

# %%
//
        'rgba(0, 255, 255, 0)',
        'rgba(0, 255, 255, 1)',
        'rgba(0, 191, 255, 1)',
        'rgba(0, 127, 255, 1)',
        'rgba(0, 63, 255, 1)',
        'rgba(0, 0, 255, 1)',
        'rgba(0, 0, 223, 1)',
        'rgba(0, 0, 191, 1)',
        'rgba(0, 0, 159, 1)',
        'rgba(0, 0, 127, 1)',
        'rgba(63, 0, 91, 1)',
        'rgba(127, 0, 63, 1)',
        'rgba(191, 0, 31, 1)',
        'rgba(255, 0, 0, 1)'
//       
        'rgba(255, 0, 0, 1)'
        'rgba(191, 0, 31, 1)',
        'rgba(127, 0, 63, 1)',
        'rgba(63, 0, 91, 1)',
        'rgba(0, 0, 127, 1)',
        'rgba(0, 0, 159, 1)',
        'rgba(0, 0, 191, 1)',
        'rgba(0, 0, 223, 1)',
        'rgba(0, 0, 255, 1)',
        'rgba(0, 63, 255, 1)',
        'rgba(0, 127, 255, 1)',
        'rgba(0, 191, 255, 1)',
        'rgba(0, 255, 255, 1)',
        'rgba(0, 0, 0, 0)',
//
        'rgba(0, 0, 0, 0)',
        'rgba(255, 0, 0, 1)',
        'rgba(170, 0, 43, 1)',
        'rgba(85, 0, 85, 1)',
       
        'rgba(0, 0, 128, 1)',
        'rgba(0, 0, 170, 1)',
        'rgba(0, 0, 213, 1)',
       
        'rgba(0, 0, 255, 1)',
        'rgba(0, 85, 255, 1)',
        'rgba(0, 170, 255, 1)',
        'rgba(0, 255, 255, 1)'
# Out:
#   File "<ipython-input-28-817b40c3a47c>", line 1
#     (/)
#      ^
# SyntaxError: invalid syntax

# %%
from bokeh.sampledata import us_states, us_counties, unemployment
from bokeh.plotting import *

# %%
us_states = us_states.data.copy()
us_counties = us_counties.data.copy()
del us_states['HI']
del us_states['AK']

# %% [markdown]
# # Choropleth - By county

# %%
state_xs = [us_states[code]['lons'] for code in us_states]
state_ys = [us_states[code]['lats'] for code in us_states]

county_xs=[us_counties[code]['lons'] for code in us_counties if us_counties[code]['state'] not in ['ak', 'hi', 'pr', 'gu', 'vi', 'mp', 'as']]
county_ys=[us_counties[code]['lats'] for code in us_counties if us_counties[code]['state'] not in ['ak', 'hi', 'pr', 'gu', 'vi', 'mp', 'as']]

#Green
#colors = ["#ffffff", "#c7e9c0", "#a1d99b", "#74c476", "#41ab5d", "#238b45", "#005a32"]

#Blue
#colors = ["#f6eff7", "#d0d1e6", "#a6bddb", "#67a9cf", "#3690c0", "#02818a", "#016450"]

#Yellow to red
#colors = ["#ffffff", "#fed976", "#feb24c", "#fd8d3c", "#fc4e2a", "#e31a1c", "#b10026"]

#Yellow to green
#colors = ["#ffffcc", "#d9f0a3", "#addd8e", "#78c679", "#41ab5d", "#238443", "#238443", "#005a32"]

#pink to purple
#colors = ["#feebe2","#fcc5c0","#fa9fb5","#f768a1","#dd3497","#ae017e","#7a0177"]

#Red
colors = ["#fee5d9","#fcbba1","#fc9272","#fb6a4a","#ef3b2c","#cb181d","#99000d"]

county_colors = []

# %%
grouped_By_County = data.groupby(['County'])

# %%
County_Counts = []
County_Names = []
County_State = []
for name, group in grouped_By_County:
    County_Counts.append(len(grouped_By_County.get_group(name)))
    County_Names.append(name)
    County_State.append(grouped_By_County.get_group(name).State.values[0])
County_Count_Dict = dict(zip(County_Names,County_Counts))
County_State_Dict = dict(zip(County_Names,County_State))

# %%
for county_id in us_counties:
    if us_counties[county_id]['state'] in ['ak', 'hi', 'pr', 'gu', 'vi', 'mp', 'as']:
        continue
    if County_Count_Dict.has_key(us_counties[county_id]['name']):
        if County_State_Dict[us_counties[county_id]['name']] == us_counties[county_id]['state'].upper():
            rate = County_Count_Dict[us_counties[county_id]['name']]
            idx = min(int(rate/6), 5) + 1
            county_colors.append(colors[idx])
        else:
            county_colors.append(colors[0])
    else:
        county_colors.append(colors[0])

# %%
output_file("Where_Rose_Goes.html", title="Where Rose Goes")

hold()

patches(county_xs, county_ys, fill_color=county_colors, fill_alpha=0.9,
        line_color=colors[2], line_width=0.1, width=1200, height=700,
        title="Where Rose Goes")
patches(state_xs, state_ys, fill_alpha=0.0, line_color=colors[3],
        line_width=.5, name="Where Rose Goes")

show()
# Out:
# Session output file 'Where_Rose_Goes.html' already exists, will be overwritten.

# %% [markdown]
# # Choropleth - By state

# %%
state_xs = [us_states[code]['lons'] for code in us_states]
state_ys = [us_states[code]['lats'] for code in us_states]

#Green
colors = ["#ffffff", "#c7e9c0", "#a1d99b", "#74c476", "#41ab5d", "#238b45", "#005a32"]

#Blue
#colors = ["#f6eff7", "#d0d1e6", "#a6bddb", "#67a9cf", "#3690c0", "#02818a", "#016450"]

#Yellow to red
#colors = ["#ffffff", "#fed976", "#feb24c", "#fd8d3c", "#fc4e2a", "#e31a1c", "#b10026"]

state_colors = []

# %%
grouped_By_State = data.groupby(['State'])

# %%
State_Counts = []
State_Names = []

for name, group in grouped_By_State:
    State_Counts.append(len(grouped_By_State.get_group(name)))
    State_Names.append(name)
State_Count_Dict = dict(zip(State_Names,State_Counts))

# %%
for state in us_states:
    tempState = state
    if state in ['ak', 'hi', 'pr', 'gu', 'vi', 'mp', 'as']:
        continue
    if State_Count_Dict.has_key(tempState.upper()):
        rate = State_Count_Dict[tempState.upper()]
        idx = min(int(rate/20), 5) + 1
        state_colors.append(colors[idx])
    else:
        state_colors.append(colors[0])

# %%
output_file("Where_Rose_Goes_State.html", title="Where Rose Goes By State")

hold()

patches(state_xs, state_ys, fill_color=state_colors, fill_alpha=0.9, line_color=colors[3],
        line_width=.5, width=1200, height=700, name="Where Rose Goes By State")

show()
# Out:
# Session output file 'Where_Rose_Goes_State.html' already exists, will be overwritten.

# %% [markdown]
# TODO - Animate (http://bokeh.pydata.org/user_guide.html) by major

# %% [markdown]
# # Scatter with Basemap

# %%
grouped_By_location = data.groupby(['CityState'])

# %%
Area = np.zeros(len(grouped_By_location))
Lats = np.zeros(len(grouped_By_location))
Lons = np.zeros(len(grouped_By_location))
i = 0
for name, group in grouped_By_location:
    Area[i] = int(np.log10((len(grouped_By_location.get_group(name))) + 1) + 1) * 3
    Lats[i] = grouped_By_location.get_group(name).iloc[0]['lats']
    Lons[i] = grouped_By_location.get_group(name).iloc[0]['lons']
    i = i + 1

# %%
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])

# setup mercator map projection.
m = Basemap(llcrnrlon=-130.,llcrnrlat=20.,urcrnrlon=-50.,urcrnrlat=50.,\
            rsphere=(6378137.00,6356752.3142),\
            resolution='l',projection='merc',\
            lat_0=-90.,lon_0=-20.,lat_ts=20.)

m.drawmapboundary(fill_color='white')
m.drawcoastlines()
m.fillcontinents(color='white',lake_color='white',zorder=0)
m.drawstates()
m.drawcountries()

for k in range(len(Area)):
    x, y = m(Lons[k], Lats[k],) # Convert lat, long to y,x
    m.plot(x,y, color = 'r',marker = 'o', markersize = Area[k], alpha=0.5)
ax.set_title('Where Rose goes')
plt.show()

# %% [markdown]
# # Heatmap with Basemap

# %%
from matplotlib import cm

# %%
fig = plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
m = Basemap(llcrnrlon=-130.,llcrnrlat=20.,urcrnrlon=-50.,urcrnrlat=50.,\
            rsphere=(6378137.00,6356752.3142),\
            resolution='l',projection='merc',\
            lat_0=-90.,lon_0=-20.,lat_ts=20.)
m.drawmapboundary(fill_color='white')
m.drawcoastlines()
m.fillcontinents(color='white',lake_color='white',zorder=0)
m.drawstates()
m.drawcountries()
x, y = m(data.lons, data.lats)
x1,y1 = m(-130., 20.)
x2,y2 = m(-50., 50.)
m.hexbin(x, y, gridsize=100, mincnt = 1, bins='log', cmap=cm.YlOrRd_r, alpha = .5)
plt.show()

# %%
fig = plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
m = Basemap(llcrnrlon=-130.,llcrnrlat=20.,urcrnrlon=-50.,urcrnrlat=50.,\
            rsphere=(6378137.00,6356752.3142),\
            resolution='l',projection='merc',\
            lat_0=-90.,lon_0=-20.,lat_ts=20.)
m.drawmapboundary(fill_color='white')
m.drawcoastlines()
m.fillcontinents(color='white',lake_color='white',zorder=0)
m.drawstates()
m.drawcountries()
x,y = m(Lons, Lats)
xx, yy= meshgrid(Lats, Lons, sparee=True)
X, Y = m(yy, xx)
Z = griddata(x, y, Area, X, Y)
m.contour(X,Y,Z,cmap = plt.cm.RdBu_r)
plt.show()

# %%
import plotly

# %%
py = plotly.plotly('IPython.Demo', '1fw3zw2o13')

# %%
data.Major.unique()
# Out:
# array(['CHE', 'ME', 'CHEM', 'CPE', 'CE', 'EE', 'CHE BE', 'BE', 'OE', 'MA',
#        'BE CS', 'CS', 'SE', 'SE CS', 'CIVIL', 'ME EE', 'AB', 'PHY', 'EP',
#        'MA ECON', 'CHE CHEM'], dtype=object)

# %%
data1 = []
temp = arange(16,255,int(1.0 *256 / len(data.groupby('State'))))
i = 0
for name, g in data.groupby('State'):
    c = "#0000" + str(hex(temp[i])[str(hex(temp[i])).find('x') + 1:-1]).upper()
    s = 10*log(len(g)+1) + 1
    dx = g.DistFromRoseHulman.median()
    for name1, g1 in g.groupby('Major'):
        mx = g1.Salary.median()
        t = ['<br> State: %s<br> Salary: %s <br> Major: %s <br>  Sample Size: %s' % (g1.State.iloc[0],str(mx), g1.Major.iloc[0], str(len(g1)))]
        d = {'name':g1.State.iloc[0],'x':dx,'y':mx,\
            'type':'scatter','mode':'markers','text':t,\
            'marker': {'size':s, 'color':c , 'opacity':0.7, 'line':{'width':1}}}
        data1.append(d)  
    i = i + 1
    #print c
        
layout = { 'showlegend':False, 'width':1000, 'height': 700, 'hovermode':'closest',\
          'title':'drag to zoom-in; double-click to zoom-out<br>shift-drag to pan' }
py.iplot(data1,layout=layout,width=1050,height=750)
# Out:
# <iframe height="800" id="igraph" scrolling="no" seamless="seamless" src="https://plot.ly/~IPython.Demo/1318/1050/750" width="1100"></iframe>

# %%
data1 = []

data_sort = data.sort('Salary').reindex()
data_sort.index.names = [None]
data_sort.index = np.arange(len(data_sort))
skip = int(90000/len(data_sort))
temp = arange(10000, 100000, skip)

for i in range(len(data)):
        s = 8
        t = ['<br> Salary: %s<br> Major: %s <br> State: %s<br> City: %s <br>' % (str(data_sort.Salary[i]),data_sort.Major[i], data_sort.State[i], data.City[i])]
        d = {'name':data_sort.Major[i],'x':i ,'y':data_sort.Salary[i],\
            'type':'scatter','mode':'markers','text':t,\
            'marker': {'size':s, 'opacity':0.7, 'line':{'width':1}}}
        data1.append(d)  
        
layout = { 'showlegend':False, 'width':1000, 'height': 700, 'hovermode':'closest',\
          'title':'drag to zoom-in; double-click to zoom-out<br>shift-drag to pan' }
py.iplot(data1,layout=layout,width=1050,height=750)
# Out:
# <iframe height="800" id="igraph" scrolling="no" seamless="seamless" src="https://plot.ly/~IPython.Demo/1310/1050/750" width="1100"></iframe>

# %%
data_sort = data.sort('Salary').reindex()
data_sort.index.names = [None]
data_sort.index = np.arange(len(data_sort))

# %%
data_sort.head()
# Out:
#            City State Major  Salary               CityState       lats  \
# 0    Louisville    KY    AB   24500    ('Louisville', 'KY')  38.252665
# 1      Fontanet    IN    ME   33000      ('Fontanet', 'IN')  39.575370
# 2  Mount Vernon    IN  CHEM   33250  ('Mount Vernon', 'IN')  37.932266
# 3     Charlotte    NC    ME   35000     ('Charlotte', 'NC')  35.227087
# 4  Mount Vernon    IN    CE   35000  ('Mount Vernon', 'IN')  37.932266
#
#         lons       County  DistFromRoseHulman  BearingFromRoseHulman
# 0 -85.758456    Jefferson          119.688192             -44.573014
# 1 -87.243482         Vigo            8.070269              54.845190
# 2 -87.895027        Posey          111.100402            -106.058895
# 3 -80.843127  Mecklenburg          461.331663             -37.503101
# 4 -87.895027        Posey          111.100402            -106.058895
